# %%
import pandas as pd

# %%
df = pd.read_csv("score_dump.csv")

df['Differential'] = pd.Series(df['Winning Score'] - df['Losing Score'])

# TODO: assign owners of each team

# %%
high_scores = df.groupby('Winning Team')

pd.concat([high_scores['Winning Score'].max(), high_scores['Losing Score'].max()], axis=1)
# Out:
#                       Winning Score  Losing Score
# Winning Team
# Avengers Athletics           138.34        123.96
# Black Bears                  165.82        133.40
# Fighting Americans           159.82        142.56
# Grid Iron Anemia             144.04        117.92
# Low Expectations             130.04        128.68
# Non-fiction People           153.44        133.84
# Non-fiction people           125.66        106.34
# Password is Taco             143.94        119.84
# RoflStompers                 122.38        110.84
# Room 262                     158.70         90.36
# Sconstance                   156.78        142.02
# The Brute Squad              141.42        124.72
# The Enigma                   123.78         89.44
# The Lincoln Lincolns         149.72        106.72
# The Moose                    102.82         87.54
# The Moose Whisperers         143.02        127.64
# The_Dark_Side                155.82        112.26
# ihavenoideawhattodo          134.58        108.70
# istilldontknowstuff          153.70        106.56
# the_Dark_Side                151.30         94.54
